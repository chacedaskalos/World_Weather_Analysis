# %%
import pandas as pd
import os
import time
from datetime import datetime
import numpy as np
import requests
from citipy import citipy

from config import weather_api_key

# %%
lats = np.random.uniform(-90.000, 90.000, size=2000) 
lngs = np.random.uniform(-180.000, 180.000, size=2000)
lat_lngs = zip(lats, lngs)
coordinates = list(lat_lngs)

# %%
cities=[]
for coordinate in coordinates:
    city=citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 781

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        weather_desc = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description" : weather_desc
                         
                         })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 2 of Set 1 | meulaboh
# Processing Record 3 of Set 1 | khonuu
# City not found. Skipping...
# Processing Record 4 of Set 1 | hilo
# Processing Record 5 of Set 1 | severo-kurilsk
# Processing Record 6 of Set 1 | longyearbyen
# Processing Record 7 of Set 1 | ushuaia
# Processing Record 8 of Set 1 | yellowknife
# Processing Record 9 of Set 1 | kaitangata
# Processing Record 10 of Set 1 | jamestown
# Processing Record 11 of Set 1 | gimli
# Processing Record 12 of Set 1 | mahebourg
# Processing Record 13 of Set 1 | butaritari
# Processing Record 14 of Set 1 | ekibastuz
# Processing Record 15 of Set 1 | gao
# Processing Record 16 of Set 1 | isangel
# Processing Record 17 of Set 1 | busselton
# Processing Record 18 of Set 1 | bluff
# Processing Record 19 of Set 1 | rio gallegos
# Processing Record 20 of Set 1 | mataura
# Processing Record 21 of Set 1 | kununurra
# Processing Record 22 of Set 1 | avarua
# Processing Record 23 of Set 1 | rikitea
# Processing Record 24 of Set 1 | chernyshevskiy
# Processing Record 25 of Set 1 | cabo san lucas
# Processing Record 26 of Set 1 | byron bay
# Processing Record 27 of Set 1 | pacific grove
# Processing Record 28 of Set 1 | conceicao do araguaia
# Processing Record 29 of Set 1 | petauke
# Processing Record 30 of Set 1 | hithadhoo
# Processing Record 31 of Set 1 | lichinga
# Processing Record 32 of Set 1 | hamilton
# Processing Record 33 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 34 of Set 1 | puerto ayora
# Processing Record 35 of Set 1 | bouar
# Processing Record 36 of Set 1 | labuhan
# Processing Record 37 of Set 1 | provideniya
# Processing Record 38 of Set 1 | ucluelet
# Processing Record 39 of Set 1 | dingle
# Processing Record 40 of Set 1 | bilma
# Processing Record 41 of Set 1 | hobart
# Processing Record 42 of Set 1 | arraial do cabo
# Processing Record 43 of Set 1 | carnarvon
# Processing Record 44 of Set 1 | sorkjosen
# Processing Record 45 of Set 1 | champerico
# Processing Record 46 of Set 1 | new norfolk
# Processing Record 47 of Set 1 | bambous virieux
# Processing Record 48 of Set 1 | khatanga
# Processing Record 49 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 50 of Set 1 | cape town
# Processing Record 1 of Set 2 | nakusp
# Processing Record 2 of Set 2 | namatanai
# Processing Record 3 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 4 of Set 2 | two rivers
# Processing Record 5 of Set 2 | prince rupert
# Processing Record 6 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 7 of Set 2 | pochutla
# Processing Record 8 of Set 2 | oranjemund
# Processing Record 9 of Set 2 | gusau
# Processing Record 10 of Set 2 | barrow
# Processing Record 11 of Set 2 | los llanos de aridane
# Processing Record 12 of Set 2 | martapura
# Processing Record 13 of Set 2 | areosa
# Processing Record 14 of Set 2 | saint-augustin
# Processing Record 15 of Set 2 | kapaa
# Processing Record 16 of Set 2 | castro
# Processing Record 17 of Set 2 | klaksvik
# Processing Record 18 of Set 2 | omboue
# Processing Record 19 of Set 2 | tabas
# Processing Record 20 of Set 2 | mehamn
# Processing Record 21 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 22 of Set 2 | shieli
# Processing Record 23 of Set 2 | noumea
# Processing Record 24 of Set 2 | otjiwarongo
# Processing Record 25 of Set 2 | dikson
# Processing Record 26 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 27 of Set 2 | pangnirtung
# Processing Record 28 of Set 2 | nikolskoye
# Processing Record 29 of Set 2 | mayo
# Processing Record 30 of Set 2 | georgetown
# Processing Record 31 of Set 2 | tasiilaq
# Processing Record 32 of Set 2 | mar del plata
# Processing Record 33 of Set 2 | ishigaki
# Processing Record 34 of Set 2 | magnolia
# Processing Record 35 of Set 2 | podgornoye
# Processing Record 36 of Set 2 | cidreira
# Processing Record 37 of Set 2 | norman wells
# Processing Record 38 of Set 2 | chokurdakh
# Processing Record 39 of Set 2 | sao filipe
# Processing Record 40 of Set 2 | hobyo
# Processing Record 41 of Set 2 | ancud
# Processing Record 42 of Set 2 | punta arenas
# Processing Record 43 of Set 2 | coihaique
# Processing Record 44 of Set 2 | lompoc
# Processing Record 45 of Set 2 | constitucion
# Processing Record 46 of Set 2 | albany
# Processing Record 47 of Set 2 | logrono
# Processing Record 48 of Set 2 | tabou
# Processing Record 49 of Set 2 | balabac
# Processing Record 50 of Set 2 | qaanaaq
# Processing Record 1 of Set 3 | atuona
# Processing Record 2 of Set 3 | lebu
# Processing Record 3 of Set 3 | saldanha
# Processing Record 4 of Set 3 | mandera
# Processing Record 5 of Set 3 | nome
# Processing Record 6 of Set 3 | katsuura
# Processing Record 7 of Set 3 | lagoa
# Processing Record 8 of Set 3 | narrabri
# Processing Record 9 of Set 3 | bogorodskoye
# Processing Record 10 of Set 3 | hermanus
# Processing Record 11 of Set 3 | le port
# Processing Record 12 of Set 3 | salalah
# Processing Record 13 of Set 3 | cherskiy
# Processing Record 14 of Set 3 | kandrian
# Processing Record 15 of Set 3 | vaini
# Processing Record 16 of Set 3 | tuktoyaktuk
# Processing Record 17 of Set 3 | porto novo
# Processing Record 18 of Set 3 | bulgan
# Processing Record 19 of Set 3 | pevek
# Processing Record 20 of Set 3 | faridan
# City not found. Skipping...
# Processing Record 21 of Set 3 | nalut
# Processing Record 22 of Set 3 | kieta
# Processing Record 23 of Set 3 | shimoda
# Processing Record 24 of Set 3 | flinders
# Processing Record 25 of Set 3 | ninotsminda
# Processing Record 26 of Set 3 | bathsheba
# Processing Record 27 of Set 3 | honiara
# Processing Record 28 of Set 3 | berlevag
# Processing Record 29 of Set 3 | jalu
# Processing Record 30 of Set 3 | menongue
# Processing Record 31 of Set 3 | thompson
# Processing Record 32 of Set 3 | bystrice pod hostynem
# Processing Record 33 of Set 3 | tyukhtet
# Processing Record 34 of Set 3 | kavaratti
# Processing Record 35 of Set 3 | bredasdorp
# Processing Record 36 of Set 3 | ambon
# Processing Record 37 of Set 3 | fortuna
# Processing Record 38 of Set 3 | upernavik
# Processing Record 39 of Set 3 | ribeira grande
# Processing Record 40 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 41 of Set 3 | cururupu
# Processing Record 42 of Set 3 | de bilt
# Processing Record 43 of Set 3 | farafangana
# Processing Record 44 of Set 3 | hukuntsi
# Processing Record 45 of Set 3 | kindu
# Processing Record 46 of Set 3 | aparecida do taboado
# Processing Record 47 of Set 3 | tual
# Processing Record 48 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 49 of Set 3 | bridlington
# Processing Record 50 of Set 3 | te anau
# Processing Record 1 of Set 4 | tabiauea
# City not found. Skipping...
# Processing Record 2 of Set 4 | mount gambier
# Processing Record 3 of Set 4 | bengkulu
# Processing Record 4 of Set 4 | kavieng
# Processing Record 5 of Set 4 | sangar
# Processing Record 6 of Set 4 | luderitz
# Processing Record 7 of Set 4 | gharb
# City not found. Skipping...
# Processing Record 8 of Set 4 | leningradskiy
# Processing Record 9 of Set 4 | olafsvik
# Processing Record 10 of Set 4 | badou
# Processing Record 11 of Set 4 | bethel
# Processing Record 12 of Set 4 | avera
# Processing Record 13 of Set 4 | rafsanjan
# Processing Record 14 of Set 4 | ahipara
# Processing Record 15 of Set 4 | sechura
# Processing Record 16 of Set 4 | itarema
# Processing Record 17 of Set 4 | viedma
# Processing Record 18 of Set 4 | semirom
# Processing Record 19 of Set 4 | nanortalik
# Processing Record 20 of Set 4 | lac-megantic
# Processing Record 21 of Set 4 | riyadh
# Processing Record 22 of Set 4 | barcelona
# Processing Record 23 of Set 4 | ngaoundere
# Processing Record 24 of Set 4 | belmonte
# Processing Record 25 of Set 4 | alofi
# Processing Record 26 of Set 4 | poum
# Processing Record 27 of Set 4 | freeport
# Processing Record 28 of Set 4 | moa
# Processing Record 29 of Set 4 | faya
# Processing Record 30 of Set 4 | husavik
# Processing Record 31 of Set 4 | laguna
# Processing Record 32 of Set 4 | chumphon
# Processing Record 33 of Set 4 | tamano
# Processing Record 34 of Set 4 | vredendal
# Processing Record 35 of Set 4 | ravar
# Processing Record 36 of Set 4 | namibe
# Processing Record 37 of Set 4 | port alfred
# Processing Record 38 of Set 4 | nizhnevartovsk
# Processing Record 39 of Set 4 | sorvag
# City not found. Skipping...
# Processing Record 40 of Set 4 | labuan
# Processing Record 41 of Set 4 | lesu
# Processing Record 42 of Set 4 | palang
# Processing Record 43 of Set 4 | punghina
# Processing Record 44 of Set 4 | saint-francois
# Processing Record 45 of Set 4 | unidad
# Processing Record 46 of Set 4 | naron
# Processing Record 47 of Set 4 | mundo nuevo
# Processing Record 48 of Set 4 | priiskovyy
# Processing Record 49 of Set 4 | faanui
# Processing Record 50 of Set 4 | puro
# Processing Record 1 of Set 5 | yumen
# Processing Record 2 of Set 5 | saint-philippe
# Processing Record 3 of Set 5 | monterotondo
# Processing Record 4 of Set 5 | komsomolskiy
# Processing Record 5 of Set 5 | rungata
# City not found. Skipping...
# Processing Record 6 of Set 5 | vossevangen
# Processing Record 7 of Set 5 | changji
# Processing Record 8 of Set 5 | berdigestyakh
# Processing Record 9 of Set 5 | brewster
# Processing Record 10 of Set 5 | artyk
# City not found. Skipping...
# Processing Record 11 of Set 5 | jaszszentlaszlo
# Processing Record 12 of Set 5 | tiksi
# Processing Record 13 of Set 5 | coquimbo
# Processing Record 14 of Set 5 | purpe
# Processing Record 15 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 16 of Set 5 | puerto escondido
# Processing Record 17 of Set 5 | tuatapere
# Processing Record 18 of Set 5 | marsh harbour
# Processing Record 19 of Set 5 | nouadhibou
# Processing Record 20 of Set 5 | tautira
# Processing Record 21 of Set 5 | pisco
# Processing Record 22 of Set 5 | osakarovka
# Processing Record 23 of Set 5 | cascais
# Processing Record 24 of Set 5 | kahului
# Processing Record 25 of Set 5 | port elizabeth
# Processing Record 26 of Set 5 | doha
# Processing Record 27 of Set 5 | fairbanks
# Processing Record 28 of Set 5 | sao felix do xingu
# Processing Record 29 of Set 5 | hambantota
# Processing Record 30 of Set 5 | meyungs
# City not found. Skipping...
# Processing Record 31 of Set 5 | torbay
# Processing Record 32 of Set 5 | solnechnyy
# Processing Record 33 of Set 5 | san cristobal
# Processing Record 34 of Set 5 | saskylakh
# Processing Record 35 of Set 5 | parabel
# Processing Record 36 of Set 5 | merauke
# Processing Record 37 of Set 5 | moron
# Processing Record 38 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 39 of Set 5 | kathmandu
# Processing Record 40 of Set 5 | marawi
# Processing Record 41 of Set 5 | sayyan
# Processing Record 42 of Set 5 | souillac
# Processing Record 43 of Set 5 | daru
# Processing Record 44 of Set 5 | corinto
# Processing Record 45 of Set 5 | yekaterinovka
# Processing Record 46 of Set 5 | ixtapa
# Processing Record 47 of Set 5 | manaure
# Processing Record 48 of Set 5 | mackay
# Processing Record 49 of Set 5 | san policarpo
# Processing Record 50 of Set 5 | nyrob
# Processing Record 1 of Set 6 | dubbo
# Processing Record 2 of Set 6 | coronado
# Processing Record 3 of Set 6 | hualmay
# Processing Record 4 of Set 6 | plaridel
# Processing Record 5 of Set 6 | viru
# Processing Record 6 of Set 6 | jumla
# Processing Record 7 of Set 6 | eyl
# Processing Record 8 of Set 6 | henties bay
# Processing Record 9 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 10 of Set 6 | urucui
# Processing Record 11 of Set 6 | inhambane
# Processing Record 12 of Set 6 | lithgow
# Processing Record 13 of Set 6 | potosi
# Processing Record 14 of Set 6 | uvat
# Processing Record 15 of Set 6 | taguatinga
# Processing Record 16 of Set 6 | mbigou
# Processing Record 17 of Set 6 | dongsheng
# Processing Record 18 of Set 6 | jizan
# Processing Record 19 of Set 6 | fort nelson
# Processing Record 20 of Set 6 | wanning
# Processing Record 21 of Set 6 | antalaha
# Processing Record 22 of Set 6 | geraldton
# Processing Record 23 of Set 6 | rodrigues alves
# Processing Record 24 of Set 6 | general pico
# Processing Record 25 of Set 6 | sofiysk
# City not found. Skipping...
# Processing Record 26 of Set 6 | iwanai
# Processing Record 27 of Set 6 | kruisfontein
# Processing Record 28 of Set 6 | north platte
# Processing Record 29 of Set 6 | yarada
# Processing Record 30 of Set 6 | berezovyy
# Processing Record 31 of Set 6 | vestmanna
# Processing Record 32 of Set 6 | waipawa
# Processing Record 33 of Set 6 | venkatagiri
# Processing Record 34 of Set 6 | stoyba
# City not found. Skipping...
# Processing Record 35 of Set 6 | westport
# Processing Record 36 of Set 6 | xining
# Processing Record 37 of Set 6 | nara
# Processing Record 38 of Set 6 | sri aman
# Processing Record 39 of Set 6 | victoria
# Processing Record 40 of Set 6 | pandan
# Processing Record 41 of Set 6 | kidal
# Processing Record 42 of Set 6 | sola
# Processing Record 43 of Set 6 | guerrero negro
# Processing Record 44 of Set 6 | kedougou
# Processing Record 45 of Set 6 | jiuquan
# Processing Record 46 of Set 6 | tazovskiy
# Processing Record 47 of Set 6 | at-bashi
# Processing Record 48 of Set 6 | kwinana
# Processing Record 49 of Set 6 | sinnamary
# Processing Record 50 of Set 6 | humaita
# Processing Record 1 of Set 7 | chuy
# Processing Record 2 of Set 7 | fukue
# Processing Record 3 of Set 7 | hays
# Processing Record 4 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 5 of Set 7 | banamba
# Processing Record 6 of Set 7 | honningsvag
# Processing Record 7 of Set 7 | buala
# Processing Record 8 of Set 7 | havoysund
# Processing Record 9 of Set 7 | port lincoln
# Processing Record 10 of Set 7 | umm lajj
# Processing Record 11 of Set 7 | korla
# Processing Record 12 of Set 7 | naryan-mar
# Processing Record 13 of Set 7 | eenhana
# Processing Record 14 of Set 7 | hornepayne
# Processing Record 15 of Set 7 | bandarban
# Processing Record 16 of Set 7 | ponta do sol
# Processing Record 17 of Set 7 | kolobrzeg
# Processing Record 18 of Set 7 | beloha
# Processing Record 19 of Set 7 | woodland
# Processing Record 20 of Set 7 | udimskiy
# Processing Record 21 of Set 7 | la ronge
# Processing Record 22 of Set 7 | piney green
# Processing Record 23 of Set 7 | tanabe
# Processing Record 24 of Set 7 | novopokrovka
# Processing Record 25 of Set 7 | ilulissat
# Processing Record 26 of Set 7 | baruun-urt
# Processing Record 27 of Set 7 | gamba
# Processing Record 28 of Set 7 | east london
# Processing Record 29 of Set 7 | saint george
# Processing Record 30 of Set 7 | necochea
# Processing Record 31 of Set 7 | porto santo
# Processing Record 32 of Set 7 | takoradi
# Processing Record 33 of Set 7 | coahuayana
# Processing Record 34 of Set 7 | port hardy
# Processing Record 35 of Set 7 | escobal
# Processing Record 36 of Set 7 | kloulklubed
# Processing Record 37 of Set 7 | ahuimanu
# Processing Record 38 of Set 7 | airai
# Processing Record 39 of Set 7 | novoanninskiy
# Processing Record 40 of Set 7 | samarai
# Processing Record 41 of Set 7 | talnakh
# Processing Record 42 of Set 7 | emerald
# Processing Record 43 of Set 7 | kadykchan
# City not found. Skipping...
# Processing Record 44 of Set 7 | elhovo
# Processing Record 45 of Set 7 | linjiang
# Processing Record 46 of Set 7 | dudinka
# Processing Record 47 of Set 7 | sovetskiy
# Processing Record 48 of Set 7 | suntar
# Processing Record 49 of Set 7 | ipixuna
# Processing Record 50 of Set 7 | trincomalee
# Processing Record 1 of Set 8 | road town
# Processing Record 2 of Set 8 | zhigansk
# Processing Record 3 of Set 8 | san patricio
# Processing Record 4 of Set 8 | boromlya
# Processing Record 5 of Set 8 | gazanjyk
# Processing Record 6 of Set 8 | kosum phisai
# Processing Record 7 of Set 8 | sitka
# Processing Record 8 of Set 8 | saint-joseph
# Processing Record 9 of Set 8 | bhimunipatnam
# Processing Record 10 of Set 8 | yomitan
# City not found. Skipping...
# Processing Record 11 of Set 8 | vardo
# Processing Record 12 of Set 8 | anadyr
# Processing Record 13 of Set 8 | algiers
# Processing Record 14 of Set 8 | port blair
# Processing Record 15 of Set 8 | indore
# Processing Record 16 of Set 8 | gazojak
# Processing Record 17 of Set 8 | rasskazovo
# Processing Record 18 of Set 8 | tokur
# Processing Record 19 of Set 8 | grindavik
# Processing Record 20 of Set 8 | kiruna
# Processing Record 21 of Set 8 | iracoubo
# Processing Record 22 of Set 8 | bandarbeyla
# Processing Record 23 of Set 8 | koslan
# Processing Record 24 of Set 8 | yingcheng
# Processing Record 25 of Set 8 | mineral wells
# Processing Record 26 of Set 8 | panuco
# Processing Record 27 of Set 8 | sur
# Processing Record 28 of Set 8 | auki
# Processing Record 29 of Set 8 | whyalla
# Processing Record 30 of Set 8 | umm kaddadah
# Processing Record 31 of Set 8 | beyneu
# Processing Record 32 of Set 8 | morondava
# Processing Record 33 of Set 8 | bereda
# Processing Record 34 of Set 8 | basar
# Processing Record 35 of Set 8 | maple creek
# Processing Record 36 of Set 8 | san quintin
# Processing Record 37 of Set 8 | egvekinot
# Processing Record 38 of Set 8 | mongo
# Processing Record 39 of Set 8 | beringovskiy
# Processing Record 40 of Set 8 | laranjeiras do sul
# Processing Record 41 of Set 8 | aswan
# Processing Record 42 of Set 8 | new castle
# Processing Record 43 of Set 8 | barillas
# Processing Record 44 of Set 8 | kilindoni
# Processing Record 45 of Set 8 | cabedelo
# Processing Record 46 of Set 8 | soe
# Processing Record 47 of Set 8 | hosakote
# Processing Record 48 of Set 8 | santa fe
# Processing Record 49 of Set 8 | luwuk
# Processing Record 50 of Set 8 | east stroudsburg
# Processing Record 1 of Set 9 | bertoua
# Processing Record 2 of Set 9 | kirakira
# Processing Record 3 of Set 9 | sanmenxia
# Processing Record 4 of Set 9 | tuy hoa
# Processing Record 5 of Set 9 | mineiros
# Processing Record 6 of Set 9 | rio tercero
# Processing Record 7 of Set 9 | kiama
# Processing Record 8 of Set 9 | asau
# Processing Record 9 of Set 9 | pitimbu
# Processing Record 10 of Set 9 | iquique
# Processing Record 11 of Set 9 | brookhaven
# Processing Record 12 of Set 9 | borba
# Processing Record 13 of Set 9 | yomou
# Processing Record 14 of Set 9 | poroshkovo
# Processing Record 15 of Set 9 | okhotsk
# Processing Record 16 of Set 9 | port hedland
# Processing Record 17 of Set 9 | mocuba
# Processing Record 18 of Set 9 | tshikapa
# Processing Record 19 of Set 9 | dilla
# Processing Record 20 of Set 9 | xinqing
# Processing Record 21 of Set 9 | asyut
# Processing Record 22 of Set 9 | daura
# Processing Record 23 of Set 9 | sines
# Processing Record 24 of Set 9 | aleksandrovskoye
# Processing Record 25 of Set 9 | presidencia roque saenz pena
# Processing Record 26 of Set 9 | isagarh
# Processing Record 27 of Set 9 | auch
# Processing Record 28 of Set 9 | riviere-au-renard
# Processing Record 29 of Set 9 | muros
# Processing Record 30 of Set 9 | kaeo
# Processing Record 31 of Set 9 | tabuk
# Processing Record 32 of Set 9 | ballina
# Processing Record 33 of Set 9 | adre
# Processing Record 34 of Set 9 | kearney
# Processing Record 35 of Set 9 | wake forest
# Processing Record 36 of Set 9 | portland
# Processing Record 37 of Set 9 | xaxim
# Processing Record 38 of Set 9 | holme
# Processing Record 39 of Set 9 | rafai
# Processing Record 40 of Set 9 | rawson
# Processing Record 41 of Set 9 | noyabrsk
# Processing Record 42 of Set 9 | lavrentiya
# Processing Record 43 of Set 9 | clyde river
# Processing Record 44 of Set 9 | codrington
# Processing Record 45 of Set 9 | christchurch
# Processing Record 46 of Set 9 | shache
# Processing Record 47 of Set 9 | aranos
# Processing Record 48 of Set 9 | cortez
# Processing Record 49 of Set 9 | mount isa
# Processing Record 50 of Set 9 | miranorte
# City not found. Skipping...
# Processing Record 1 of Set 10 | grand centre
# City not found. Skipping...
# Processing Record 2 of Set 10 | alta floresta
# Processing Record 3 of Set 10 | ginda
# Processing Record 4 of Set 10 | lerwick
# Processing Record 5 of Set 10 | fujin
# Processing Record 6 of Set 10 | oruro
# Processing Record 7 of Set 10 | benguela
# Processing Record 8 of Set 10 | atar
# Processing Record 9 of Set 10 | bambanglipuro
# Processing Record 10 of Set 10 | karratha
# Processing Record 11 of Set 10 | sebeta
# Processing Record 12 of Set 10 | ilinskiy
# Processing Record 13 of Set 10 | manggar
# Processing Record 14 of Set 10 | zonguldak
# Processing Record 15 of Set 10 | manitouwadge
# Processing Record 16 of Set 10 | lang suan
# Processing Record 17 of Set 10 | brae
# Processing Record 18 of Set 10 | aflao
# Processing Record 19 of Set 10 | buariki
# City not found. Skipping...
# Processing Record 20 of Set 10 | narsaq
# Processing Record 21 of Set 10 | dovers
# Processing Record 22 of Set 10 | balikpapan
# Processing Record 23 of Set 10 | nipawin
# Processing Record 24 of Set 10 | pemangkat
# Processing Record 25 of Set 10 | simi
# Processing Record 26 of Set 10 | yinchuan
# Processing Record 27 of Set 10 | lata
# Processing Record 28 of Set 10 | phangnga
# Processing Record 29 of Set 10 | college
# Processing Record 30 of Set 10 | batagay-alyta
# Processing Record 31 of Set 10 | yar-sale
# Processing Record 32 of Set 10 | sobolevo
# Processing Record 33 of Set 10 | tilichiki
# Processing Record 34 of Set 10 | nizhneyansk
# City not found. Skipping...
# Processing Record 35 of Set 10 | vestmannaeyjar
# Processing Record 36 of Set 10 | simao
# Processing Record 37 of Set 10 | tarudant
# City not found. Skipping...
# Processing Record 38 of Set 10 | kodiak
# Processing Record 39 of Set 10 | great falls
# Processing Record 40 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 41 of Set 10 | chimbarongo
# Processing Record 42 of Set 10 | mwinilunga
# Processing Record 43 of Set 10 | buchanan
# Processing Record 44 of Set 10 | adrar
# Processing Record 45 of Set 10 | doka
# Processing Record 46 of Set 10 | san bartolome de tirajana
# Processing Record 47 of Set 10 | saiha
# Processing Record 48 of Set 10 | borovoy
# Processing Record 49 of Set 10 | malwan
# City not found. Skipping...
# Processing Record 50 of Set 10 | ostrovnoy
# Processing Record 1 of Set 11 | arman
# Processing Record 2 of Set 11 | spearfish
# Processing Record 3 of Set 11 | perisani
# Processing Record 4 of Set 11 | tigil
# Processing Record 5 of Set 11 | yanan
# City not found. Skipping...
# Processing Record 6 of Set 11 | thunder bay
# Processing Record 7 of Set 11 | sakaiminato
# Processing Record 8 of Set 11 | catuday
# Processing Record 9 of Set 11 | mezen
# Processing Record 10 of Set 11 | nuuk
# Processing Record 11 of Set 11 | san agustin acasaguastlan
# Processing Record 12 of Set 11 | jaffna
# Processing Record 13 of Set 11 | bubaque
# Processing Record 14 of Set 11 | tefe
# Processing Record 15 of Set 11 | aksu
# Processing Record 16 of Set 11 | juneau
# Processing Record 17 of Set 11 | nassjo
# Processing Record 18 of Set 11 | ercis
# Processing Record 19 of Set 11 | santa marta
# Processing Record 20 of Set 11 | mitu
# Processing Record 21 of Set 11 | marfino
# Processing Record 22 of Set 11 | biak
# Processing Record 23 of Set 11 | manokwari
# Processing Record 24 of Set 11 | huron
# Processing Record 25 of Set 11 | vila franca do campo
# Processing Record 26 of Set 11 | tierranueva
# Processing Record 27 of Set 11 | broken hill
# Processing Record 28 of Set 11 | havelock
# Processing Record 29 of Set 11 | hunza
# City not found. Skipping...
# Processing Record 30 of Set 11 | ambanja
# Processing Record 31 of Set 11 | pangody
# Processing Record 32 of Set 11 | vila velha
# Processing Record 33 of Set 11 | maniitsoq
# Processing Record 34 of Set 11 | vao
# Processing Record 35 of Set 11 | anqing
# Processing Record 36 of Set 11 | meaford
# Processing Record 37 of Set 11 | cabra
# Processing Record 38 of Set 11 | kupang
# Processing Record 39 of Set 11 | bintulu
# Processing Record 40 of Set 11 | malokakhovka
# Processing Record 41 of Set 11 | tezpur
# Processing Record 42 of Set 11 | bairiki
# Processing Record 43 of Set 11 | krasnovishersk
# Processing Record 44 of Set 11 | moanda
# Processing Record 45 of Set 11 | hihifo
# City not found. Skipping...
# Processing Record 46 of Set 11 | pallasovka
# Processing Record 47 of Set 11 | jodhpur
# Processing Record 48 of Set 11 | yekimovichi
# Processing Record 49 of Set 11 | acapulco
# Processing Record 50 of Set 11 | zadar
# Processing Record 1 of Set 12 | batticaloa
# Processing Record 2 of Set 12 | zavallya
# Processing Record 3 of Set 12 | monrovia
# Processing Record 4 of Set 12 | labutta
# City not found. Skipping...
# Processing Record 5 of Set 12 | mehran
# Processing Record 6 of Set 12 | shahpur
# Processing Record 7 of Set 12 | peniche
# Processing Record 8 of Set 12 | kizukuri
# Processing Record 9 of Set 12 | billings
# Processing Record 10 of Set 12 | vahan
# Processing Record 11 of Set 12 | hovd
# Processing Record 12 of Set 12 | boksitogorsk
# Processing Record 13 of Set 12 | turtkul
# City not found. Skipping...
# Processing Record 14 of Set 12 | morehead
# Processing Record 15 of Set 12 | zaykovo
# Processing Record 16 of Set 12 | sungairaya
# Processing Record 17 of Set 12 | esperance
# Processing Record 18 of Set 12 | vostok
# Processing Record 19 of Set 12 | puerto madryn
# Processing Record 20 of Set 12 | surt
# Processing Record 21 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 22 of Set 12 | katwijk
# Processing Record 23 of Set 12 | kropotkin
# Processing Record 24 of Set 12 | phan thiet
# Processing Record 25 of Set 12 | ekhabi
# Processing Record 26 of Set 12 | juifang
# City not found. Skipping...
# Processing Record 27 of Set 12 | touros
# Processing Record 28 of Set 12 | huanren
# Processing Record 29 of Set 12 | falmouth
# Processing Record 30 of Set 12 | lysva
# Processing Record 31 of Set 12 | paslek
# Processing Record 32 of Set 12 | torrijos
# Processing Record 33 of Set 12 | altea
# Processing Record 34 of Set 12 | port-gentil
# Processing Record 35 of Set 12 | duz
# City not found. Skipping...
# Processing Record 36 of Set 12 | lasa
# Processing Record 37 of Set 12 | san rafael
# Processing Record 38 of Set 12 | port shepstone
# Processing Record 39 of Set 12 | aklavik
# Processing Record 40 of Set 12 | sassandra
# Processing Record 41 of Set 12 | zheshart
# Processing Record 42 of Set 12 | chapais
# Processing Record 43 of Set 12 | tasbuget
# City not found. Skipping...
# Processing Record 44 of Set 12 | andilamena
# Processing Record 45 of Set 12 | pietersburg
# Processing Record 46 of Set 12 | ilhabela
# Processing Record 47 of Set 12 | grand gaube
# Processing Record 48 of Set 12 | praia
# Processing Record 49 of Set 12 | poya
# Processing Record 50 of Set 12 | salamiyah
# Processing Record 1 of Set 13 | haukipudas
# Processing Record 2 of Set 13 | storforshei
# Processing Record 3 of Set 13 | lorengau
# Processing Record 4 of Set 13 | talaya
# Processing Record 5 of Set 13 | haveli
# Processing Record 6 of Set 13 | evensk
# Processing Record 7 of Set 13 | stornoway
# Processing Record 8 of Set 13 | quesnel
# Processing Record 9 of Set 13 | kaniama
# Processing Record 10 of Set 13 | malpe
# Processing Record 11 of Set 13 | chicomuselo
# Processing Record 12 of Set 13 | teluknaga
# Processing Record 13 of Set 13 | gizo
# Processing Record 14 of Set 13 | tromso
# Processing Record 15 of Set 13 | palmer
# Processing Record 16 of Set 13 | shingu
# Processing Record 17 of Set 13 | fort saint john
# City not found. Skipping...
# Processing Record 18 of Set 13 | san jacinto
# Processing Record 19 of Set 13 | general roca
# Processing Record 20 of Set 13 | svobody
# Processing Record 21 of Set 13 | ihosy
# Processing Record 22 of Set 13 | alexandria
# Processing Record 23 of Set 13 | skalistyy
# City not found. Skipping...
# Processing Record 24 of Set 13 | bam
# Processing Record 25 of Set 13 | biltine
# Processing Record 26 of Set 13 | maragogi
# Processing Record 27 of Set 13 | karakol
# Processing Record 28 of Set 13 | corni
# Processing Record 29 of Set 13 | yarmouth
# Processing Record 30 of Set 13 | usolye
# Processing Record 31 of Set 13 | naze
# Processing Record 32 of Set 13 | shelburne
# Processing Record 33 of Set 13 | we
# City not found. Skipping...
# Processing Record 34 of Set 13 | semnan
# Processing Record 35 of Set 13 | dunedin
# Processing Record 36 of Set 13 | nevers
# Processing Record 37 of Set 13 | anjozorobe
# Processing Record 38 of Set 13 | uray
# Processing Record 39 of Set 13 | nyurba
# Processing Record 40 of Set 13 | alice springs
# Processing Record 41 of Set 13 | gat
# Processing Record 42 of Set 13 | iqaluit
# Processing Record 43 of Set 13 | paradwip
# City not found. Skipping...
# Processing Record 44 of Set 13 | blagoyevo
# Processing Record 45 of Set 13 | bugiri
# Processing Record 46 of Set 13 | hasaki
# Processing Record 47 of Set 13 | saint-georges
# Processing Record 48 of Set 13 | balasesti
# Processing Record 49 of Set 13 | tchollire
# Processing Record 50 of Set 13 | katete
# Processing Record 1 of Set 14 | makakilo city
# Processing Record 2 of Set 14 | fredericksburg
# Processing Record 3 of Set 14 | haines junction
# Processing Record 4 of Set 14 | houma
# Processing Record 5 of Set 14 | wharton
# Processing Record 6 of Set 14 | puerto suarez
# Processing Record 7 of Set 14 | civita castellana
# Processing Record 8 of Set 14 | gboko
# Processing Record 9 of Set 14 | labinsk
# Processing Record 10 of Set 14 | waingapu
# Processing Record 11 of Set 14 | arlit
# Processing Record 12 of Set 14 | vanimo
# Processing Record 13 of Set 14 | gidole
# Processing Record 14 of Set 14 | halalo
# City not found. Skipping...
# Processing Record 15 of Set 14 | mwanza
# Processing Record 16 of Set 14 | grahamstown
# Processing Record 17 of Set 14 | olinda
# Processing Record 18 of Set 14 | cayenne
# Processing Record 19 of Set 14 | san nicolas
# Processing Record 20 of Set 14 | ondorhaan
# City not found. Skipping...
# Processing Record 21 of Set 14 | campobello di licata
# Processing Record 22 of Set 14 | huarmey
# Processing Record 23 of Set 14 | aykhal
# Processing Record 24 of Set 14 | mariental
# Processing Record 25 of Set 14 | price
# Processing Record 26 of Set 14 | zemio
# Processing Record 27 of Set 14 | gornopravdinsk
# Processing Record 28 of Set 14 | khuzhir
# Processing Record 29 of Set 14 | digby
# Processing Record 30 of Set 14 | calvinia
# Processing Record 31 of Set 14 | trairi
# Processing Record 32 of Set 14 | mindelo
# Processing Record 33 of Set 14 | valentin gomez farias
# Processing Record 34 of Set 14 | dzhusaly
# City not found. Skipping...
# Processing Record 35 of Set 14 | tamala
# Processing Record 36 of Set 14 | samusu
# City not found. Skipping...
# Processing Record 37 of Set 14 | nantucket
# Processing Record 38 of Set 14 | adana
# Processing Record 39 of Set 14 | sao joao da barra
# Processing Record 40 of Set 14 | ilo
# Processing Record 41 of Set 14 | tsienyane
# City not found. Skipping...
# Processing Record 42 of Set 14 | acarau
# Processing Record 43 of Set 14 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 44 of Set 14 | vaovai
# City not found. Skipping...
# Processing Record 45 of Set 14 | barawe
# City not found. Skipping...
# Processing Record 46 of Set 14 | kaifeng
# Processing Record 47 of Set 14 | ahumada
# City not found. Skipping...
# Processing Record 48 of Set 14 | luganville
# Processing Record 49 of Set 14 | kalianget
# Processing Record 50 of Set 14 | basco
# Processing Record 1 of Set 15 | polis
# Processing Record 2 of Set 15 | warmbad
# Processing Record 3 of Set 15 | starogard gdanski
# Processing Record 4 of Set 15 | barbar
# City not found. Skipping...
# Processing Record 5 of Set 15 | ruidoso
# Processing Record 6 of Set 15 | svetlaya
# Processing Record 7 of Set 15 | puerto leguizamo
# Processing Record 8 of Set 15 | ippy
# Processing Record 9 of Set 15 | bom jardim
# Processing Record 10 of Set 15 | bonavista
# Processing Record 11 of Set 15 | varena
# Processing Record 12 of Set 15 | itajai
# Processing Record 13 of Set 15 | fare
# Processing Record 14 of Set 15 | fortuna foothills
# Processing Record 15 of Set 15 | kimbe
# Processing Record 16 of Set 15 | maldonado
# Processing Record 17 of Set 15 | iranshahr
# Processing Record 18 of Set 15 | abeokuta
# Processing Record 19 of Set 15 | tamale
# Processing Record 20 of Set 15 | pogranichnyy
# Processing Record 21 of Set 15 | lewistown
# Processing Record 22 of Set 15 | xiaoshi
# Processing Record 23 of Set 15 | jasper
# Processing Record 24 of Set 15 | wawa
# Processing Record 25 of Set 15 | natal
# Processing Record 26 of Set 15 | carutapera
# Processing Record 27 of Set 15 | dzhebariki-khaya
# Processing Record 28 of Set 15 | guano
# Processing Record 29 of Set 15 | frutal
# Processing Record 30 of Set 15 | erenhot
# Processing Record 31 of Set 15 | kintinku
# Processing Record 32 of Set 15 | voh
# Processing Record 33 of Set 15 | sainte-suzanne
# Processing Record 34 of Set 15 | yamada
# Processing Record 35 of Set 15 | fomboni
# Processing Record 36 of Set 15 | hami
# Processing Record 37 of Set 15 | dubenskiy
# City not found. Skipping...
# Processing Record 38 of Set 15 | tome-acu
# City not found. Skipping...
# Processing Record 39 of Set 15 | sisimiut
# Processing Record 40 of Set 15 | aran
# Processing Record 41 of Set 15 | lamballe
# Processing Record 42 of Set 15 | tukrah
# Processing Record 43 of Set 15 | bayan
# Processing Record 44 of Set 15 | naberera
# Processing Record 45 of Set 15 | inuvik
# Processing Record 46 of Set 15 | brantford
# Processing Record 47 of Set 15 | anar darreh
# City not found. Skipping...
# Processing Record 48 of Set 15 | odweyne
# Processing Record 49 of Set 15 | palmerston
# Processing Record 50 of Set 15 | khorramshahr
# Processing Record 1 of Set 16 | caravelas
# Processing Record 2 of Set 16 | akdagmadeni
# Processing Record 3 of Set 16 | qasigiannguit
# Processing Record 4 of Set 16 | sabang
# Processing Record 5 of Set 16 | yenagoa
# Processing Record 6 of Set 16 | kashi
# Processing Record 7 of Set 16 | qaqortoq
# Processing Record 8 of Set 16 | jetis
# Processing Record 9 of Set 16 | gander
# Processing Record 10 of Set 16 | fushun
# Processing Record 11 of Set 16 | komsomolsk
# Processing Record 12 of Set 16 | wilmington
# Processing Record 13 of Set 16 | shelui
# Processing Record 14 of Set 16 | tidore
# City not found. Skipping...
# Processing Record 15 of Set 16 | izumrud
# Processing Record 16 of Set 16 | laramie
# Processing Record 17 of Set 16 | vila
# Processing Record 18 of Set 16 | ubon ratchathani
# Processing Record 19 of Set 16 | port hawkesbury
# Processing Record 20 of Set 16 | stromness
# Processing Record 21 of Set 16 | lima
# Processing Record 22 of Set 16 | uige
# Processing Record 23 of Set 16 | lolua
# City not found. Skipping...
# Processing Record 24 of Set 16 | maloshuyka
# City not found. Skipping...
# Processing Record 25 of Set 16 | padang
# Processing Record 26 of Set 16 | anloga
# Processing Record 27 of Set 16 | turan
# Processing Record 28 of Set 16 | ust-kulom
# Processing Record 29 of Set 16 | bohdan
# Processing Record 30 of Set 16 | morro bay
# Processing Record 31 of Set 16 | paamiut
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Meulaboh   4.1363   96.1285     75.34        86         100
# 1            Hilo  19.7297 -155.0900     78.12        80          56
# 2  Severo-Kurilsk  50.6789  156.1250     28.17        86         100
# 3    Longyearbyen  78.2186   15.6401      8.44        61          20
# 4         Ushuaia -54.8000  -68.3000     56.82        82          75
# 5     Yellowknife  62.4560 -114.3525     -9.58        85          75
# 6      Kaitangata -46.2817  169.8464     54.93        80          93
# 7       Jamestown  42.0970  -79.2353     23.29        38         100
# 8           Gimli  50.6336  -96.9907     11.12        66         100
# 9       Mahebourg -20.4081   57.7000     79.25        89          40
#
#    Wind Speed Country                 Date Current Description
# 0        5.79      ID  2022-02-05 20:56:12     overcast clouds
# 1        5.99      US  2022-02-05 20:56:07       broken clouds
# 2        5.91      RU  2022-02-05 20:56:13          light snow
# 3       19.57      SJ  2022-02-05 20:56:14          few clouds
# 4       27.63      AR  2022-02-05 20:56:06          light rain
# 5        6.91      CA  2022-02-05 20:56:14          light snow
# 6        5.70      NZ  2022-02-05 20:55:14     overcast clouds
# 7        3.00      US  2022-02-05 20:56:02     overcast clouds
# 8        6.91      CA  2022-02-05 20:56:15     overcast clouds
# 9       11.50      MU  2022-02-05 20:55:07    scattered clouds

# %%
new_column_order = ["City",
                    "Country",
                
                    "Lat",
                    "Lng",
                    "Max Temp",
                    "Humidity",
                    "Cloudiness",
                    "Wind Speed",
                    "Current Description"]
city_data_df=city_data_df[new_column_order]
city_data_df.head()
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Meulaboh      ID   4.1363   96.1285     75.34        86         100
# 1            Hilo      US  19.7297 -155.0900     78.12        80          56
# 2  Severo-Kurilsk      RU  50.6789  156.1250     28.17        86         100
# 3    Longyearbyen      SJ  78.2186   15.6401      8.44        61          20
# 4         Ushuaia      AR -54.8000  -68.3000     56.82        82          75
#
#    Wind Speed Current Description
# 0        5.79     overcast clouds
# 1        5.99       broken clouds
# 2        5.91          light snow
# 3       19.57          few clouds
# 4       27.63          light rain

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
